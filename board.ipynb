# %%
import chessdotcom

# %%
monthdict = {
    2023: [9,10,11,12],
    2024: [1,2,3,4,5,6,7]
}

allgamesbymonth={}

for yr, mts in monthdict.items():
    for mt in mts:
        key = f"{yr}:{mt}"
        allgamesbymonth[key] = chessdotcom.get_player_games_by_month_pgn("belingus", yr, mt)

# %%
allgamesbymonth.keys()
# Out:
# dict_keys(['2023:9', '2023:10', '2023:11', '2023:12', '2024:1', '2024:2', '2024:3', '2024:4', '2024:5', '2024:6', '2024:7'])

# %%
allgames['2023:9']
# Out:
# ChessDotComResponse(json={'pgn': {'pgn': '[Event "Live Chess"]\n[Site "Chess.com"]\n[Date "2023.09.09"]\n[Round "-"]\n[White "sanya_kedr"]\n[Black "belingus"]\n[Result "1-0"]\n[CurrentPosition "r2qkb1r/2p1pp2/pp3np1/3p2Np/2BnNP2/1P6/P1PP2PP/R1BQR1K1 b kq -"]\n[Timezone "UTC"]\n[ECO "B02"]\n[ECOUrl "https://www.chess.com/openings/Alekhines-Defense-2.Nc3"]\n[UTCDate "2023.09.09"]\n[UTCTime "19:07:51"]\n[WhiteElo "210"]\n[BlackElo "261"]\n[TimeControl "600"]\n[Termination "sanya_kedr won - game abandoned"]\n[StartTime "19:07:51"]\n[EndDate "2023.09.09"]\n[EndTime "19:19:47"]\n[Link "https://www.chess.com/game/live/81576798542"]\n\n1. e4 {[%clk 0:09:58.7]} 1... Nf6 {[%clk 0:09:56.4]} 2. Nc3 {[%clk 0:09:54]} 2... b6 {[%clk 0:09:53.7]} 3. Bb5 {[%clk 0:09:46.9]} 3... Bb7 {[%clk 0:09:48.7]} 4. f3 {[%clk 0:09:40.4]} 4... a6 {[%clk 0:09:42.8]} 5. Bc4 {[%clk 0:09:25]} 5... Nc6 {[%clk 0:09:32.4]} 6. Nh3 {[%clk 0:09:16]} 6... Nd4 {[%clk 0:09:26.8]} 7. O-O {[%clk 0:09:10.5]} 7... Bc6 {[%clk 0:09:1
# ...

# %%
del allgames
